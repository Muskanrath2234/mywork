# %%
# basic

# %%
# seprate value based on datatype

# %%
# sciling

# %%
# add new column

# %%
#

# %%
import pandas as pd

# %%
df= pd.read_csv("uk-500.csv")

# %%
df.head()
# Out:
#   first_name   last_name             company_name            address  \
# 0    Aleshia  Tomkiewicz  Alan D Rosenburg Cpa Pc       14 Taylor St
# 1       Evan   Zigomalas       Cap Gemini America        5 Binney St
# 2     France     Andrade      Elliott, John W Esq       8 Moor Place
# 3    Ulysses   Mcwalters           Mcmahan, Ben L      505 Exeter Rd
# 4     Tyisha      Veness           Champagne Room  5396 Forth Street
#
#                              city           county    postal        phone1  \
# 0               St. Stephens Ward             Kent   CT2 7PP  01835-703597
# 1                      Abbey Ward  Buckinghamshire  HP11 2AX  01937-864715
# 2  East Southbourne and Tuckton W      Bournemouth   BH6 3BE  01347-368222
# 3              Hawerby cum Beesby     Lincolnshire  DN36 5RP  01912-771311
# 4      Greets Green and Lyng Ward    West Midlands   B70 9DT  01547-429341
#
#          phone2                       email  \
# 0  01944-369967     atomkiewicz@hotmail.com
# ...

# %%
df[['first_name','web','city']]
# Out:
#     first_name                                          web  \
# 0      Aleshia         http://www.alandrosenburgcpapc.co.uk
# 1         Evan            http://www.capgeminiamerica.co.uk
# 2       France             http://www.elliottjohnwesq.co.uk
# 3      Ulysses                 http://www.mcmahanbenl.co.uk
# 4       Tyisha               http://www.champagneroom.co.uk
# ..         ...                                          ...
# 495      Avery    http://www.plazagourmetdelicatessen.co.uk
# 496       Reid           http://www.fitzgeraldedwardj.co.uk
# 497  Charlette             http://www.fureyassociates.co.uk
# 498  Celestina       http://www.bfgfederalcreditunion.co.uk
# 499         Mi  http://www.nelsonwrighthaworthgolfcrs.co.uk
#
#                                city
# 0                 St. Stephens Ward
# 1                        Abbey Ward
# 2    East Southbourne and Tuckton W
# 3                Hawerby cum Beesby
# 4        Greets Green and Lyng Ward
# ...

# %%
df.dtypes == 'object'
# Out:
# first_name      True
# last_name       True
# company_name    True
# address         True
# city            True
# county          True
# postal          True
# phone1          True
# phone2          True
# email           True
# web             True
# dtype: bool

# %%
df.isnull()
# Out:
#      first_name  last_name  company_name  address   city  county  postal  \
# 0         False      False         False    False  False   False   False
# 1         False      False         False    False  False   False   False
# 2         False      False         False    False  False   False   False
# 3         False      False         False    False  False   False   False
# 4         False      False         False    False  False   False   False
# ..          ...        ...           ...      ...    ...     ...     ...
# 495       False      False         False    False  False   False   False
# 496       False      False         False    False  False   False   False
# 497       False      False         False    False  False   False   False
# 498       False      False         False    False  False   False   False
# 499       False      False         False    False  False   False   False
#
#      phone1  phone2  email    web
# 0     False   False  False  False
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# first_name      object
# last_name       object
# company_name    object
# address         object
# city            object
# county          object
# postal          object
# phone1          object
# phone2          object
# email           object
# web             object
# dtype: object

# %%
df.describe()
# Out:
#        first_name last_name      company_name       address  \
# count         500       500               500           500
# unique        479       498               498           500
# top       Antonio     Rampy  Martin Morrissey  14 Taylor St
# freq            3         2                 2             1
#
#                          city          county   postal        phone1  \
# count                     500             500      500           500
# unique                    468             102      500           500
# top     City and Hunslet Ward  Greater London  CT2 7PP  01835-703597
# freq                        3              44        1             1
#
#               phone2                    email  \
# count            500                      500
# unique           500                      500
# top     01944-369967  atomkiewicz@hotmail.com
# freq               1                        1
#
#                                      web
# ...

# %%
df.dtypes
# Out:
# first_name      object
# last_name       object
# company_name    object
# address         object
# city            object
# county          object
# postal          object
# phone1          object
# phone2          object
# email           object
# web             object
# dtype: object

# %%
df.dtypes == 'object'
# Out:
# first_name      True
# last_name       True
# company_name    True
# address         True
# city            True
# county          True
# postal          True
# phone1          True
# phone2          True
# email           True
# web             True
# dtype: bool

# %%
df.dtypes[df.dtypes == 'object']
# Out:
# first_name      object
# last_name       object
# company_name    object
# address         object
# city            object
# county          object
# postal          object
# phone1          object
# phone2          object
# email           object
# web             object
# dtype: object

# %%
df.dtypes == 'int'
# Out:
# first_name      False
# last_name       False
# company_name    False
# address         False
# city            False
# county          False
# postal          False
# phone1          False
# phone2          False
# email           False
# web             False
# dtype: bool

# %%
df.dtypes[df.dtypes == 'object'].index
# Out:
# Index(['first_name', 'last_name', 'company_name', 'address', 'city', 'county',
#        'postal', 'phone1', 'phone2', 'email', 'web'],
#       dtype='object')

# %%
type(df.dtypes == 'object')
# Out:
# pandas.core.series.Series

# %%
df[df.dtypes[df.dtypes == 'object'].index]
# Out:
#     first_name   last_name                    company_name  \
# 0      Aleshia  Tomkiewicz         Alan D Rosenburg Cpa Pc
# 1         Evan   Zigomalas              Cap Gemini America
# 2       France     Andrade             Elliott, John W Esq
# 3      Ulysses   Mcwalters                  Mcmahan, Ben L
# 4       Tyisha      Veness                  Champagne Room
# ..         ...         ...                             ...
# 495      Avery        Veit      Plaza Gourmet Delicatessen
# 496       Reid     Euresti            Fitzgerald, Edward J
# 497  Charlette    Brenning              Furey & Associates
# 498  Celestina       Keeny        Bfg Federal Credit Union
# 499         Mi      Richan  Nelson Wright Haworth Golf Crs
#
#                 address                            city           county  \
# 0          14 Taylor St               St. Stephens Ward             Kent
# 1           5 Binney St                      Abbey Ward  Buckinghamshire
# ...

# %%
df[df.dtypes[df.dtypes == 'object'].index].describe()
# Out:
#        first_name last_name      company_name       address  \
# count         500       500               500           500
# unique        479       498               498           500
# top       Antonio     Rampy  Martin Morrissey  14 Taylor St
# freq            3         2                 2             1
#
#                          city          county   postal        phone1  \
# count                     500             500      500           500
# unique                    468             102      500           500
# top     City and Hunslet Ward  Greater London  CT2 7PP  01835-703597
# freq                        3              44        1             1
#
#               phone2                    email  \
# count            500                      500
# unique           500                      500
# top     01944-369967  atomkiewicz@hotmail.com
# freq               1                        1
#
#                                      web
# ...

# %%
# handling missing value

# %%
data= pd.read_csv("titanic.csv")

# %%
data.head(4)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
data.dtypes == 'object'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
data.dtypes == 'int64'
# Out:
# PassengerId     True
# Survived        True
# Pclass          True
# Name           False
# Sex            False
# Age            False
# SibSp           True
# Parch           True
# Ticket         False
# Fare           False
# Cabin          False
# Embarked       False
# dtype: bool

# %%
data.dtypes[ data.dtypes == 'object']
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
data.dtypes[data.dtypes =='int64']
# Out:
# PassengerId    int64
# Survived       int64
# Pclass         int64
# SibSp          int64
# Parch          int64
# dtype: object

# %%
data[data.dtypes[data.dtypes =='int64'].index].describe()
# Out:
#        PassengerId    Survived      Pclass       SibSp       Parch
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642    0.523008    0.381594
# std     257.353842    0.486592    0.836071    1.102743    0.806057
# min       1.000000    0.000000    1.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000    0.000000    0.000000
# 50%     446.000000    0.000000    3.000000    0.000000    0.000000
# 75%     668.500000    1.000000    3.000000    1.000000    0.000000
# max     891.000000    1.000000    3.000000    8.000000    6.000000

# %%
data[data.dtypes[data.dtypes =='object'].index].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
data.dtypes== 'float64'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare            True
# Cabin          False
# Embarked       False
# dtype: bool

# %%
data.dtypes[data.dtypes == 'float64']
# Out:
# Age     float64
# Fare    float64
# dtype: object

# %%
data.dtypes[data.dtypes=='float64'].index
# Out:
# Index(['Age', 'Fare'], dtype='object')

# %%
data[data.dtypes[data.dtypes=='float64'].index]
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
data[data.dtypes[data.dtypes == 'object'].index]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
[data.dtypes].index
# Out:
# <function list.index(value, start=0, stop=9223372036854775807, /)>

# %%
data.dtypes =='float64'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare            True
# Cabin          False
# Embarked       False
# dtype: bool

# %%
data.dtypes[data.dtypes =='float64'].index
# Out:
# Index(['Age', 'Fare'], dtype='object')

# %%
data[data.dtypes[data.dtypes == 'float64'].index]
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
data[['Ticket']]
# Out:
#                Ticket
# 0           A/5 21171
# 1            PC 17599
# 2    STON/O2. 3101282
# 3              113803
# 4              373450
# ..                ...
# 886            211536
# 887            112053
# 888        W./C. 6607
# 889            111369
# 890            370376
#
# [891 rows x 1 columns]

# %%
# n to n

# %%
data[['Fare']][4:10]
# Out:
#       Fare
# 4   8.0500
# 5   8.4583
# 6  51.8625
# 7  21.0750
# 8  11.1333
# 9  30.0708

# %%
data[['Fare']][5:9]
# Out:
#       Fare
# 5   8.4583
# 6  51.8625
# 7  21.0750
# 8  11.1333

# %%
data[['Fare']][10:100:20]
# Out:
#        Fare
# 10  16.7000
# 30  27.7208
# 50  39.6875
# 70  10.5000
# 90   8.0500

# %%
data[["Fare"]][-6:-1]
# Out:
#        Fare
# 885  29.125
# 886  13.000
# 887  30.000
# 888  23.450
# 889  30.000

# %%
data[["Fare"]][6:-1]
# Out:
#         Fare
# 6    51.8625
# 7    21.0750
# 8    11.1333
# 9    30.0708
# 10   16.7000
# ..       ...
# 885  29.1250
# 886  13.0000
# 887  30.0000
# 888  23.4500
# 889  30.0000
#
# [884 rows x 1 columns]

# %%
data[["Fare"]][-1:6]
# Out:
# Empty DataFrame
# Columns: [Fare]
# Index: []

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# add new column

# %%
data ['new_col']=0

# %%
# column ko jo nya nam dege agr vo phle se hi he to uska data overwrite ho jayega

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data['my_data'] =2

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data["sum"]= data["PassengerId"]+data["Age"]

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data[["Age","PassengerId","sum"]]
# Out:
#       Age  PassengerId    sum
# 0    22.0            1   23.0
# 1    38.0            2   40.0
# 2    26.0            3   29.0
# 3    35.0            4   39.0
# 4    35.0            5   40.0
# ..    ...          ...    ...
# 886  27.0          887  914.0
# 887  19.0          888  907.0
# 888   NaN          889    NaN
# 889  26.0          890  916.0
# 890  32.0          891  923.0
#
# [891 rows x 3 columns]

# %%
data["info"]=data["Sex"]+data["Name"]

# %%
data[["info"]][1:4]
# Out:
#                                                 info
# 1  femaleCumings, Mrs. John Bradley (Florence Bri...
# 2                       femaleHeikkinen, Miss. Laina
# 3  femaleFutrelle, Mrs. Jacques Heath (Lily May P...

# %%
data[["Pclass"]]
# Out:
#      Pclass
# 0         3
# 1         1
# 2         3
# 3         1
# 4         3
# ..      ...
# 886       2
# 887       1
# 888       3
# 889       1
# 890       3
#
# [891 rows x 1 columns]

# %%
pd.Categorical(data["Pclass"])
# Out:
# [3, 1, 3, 1, 3, ..., 2, 1, 3, 1, 3]
# Length: 891
# Categories (3, int64): [1, 2, 3]

# %%
pd.Categorical(data["Name"])
# Out:
# ['Braund, Mr. Owen Harris', 'Cumings, Mrs. John Bradley (Florence Briggs T..., 'Heikkinen, Miss. Laina', 'Futrelle, Mrs. Jacques Heath (Lily May Peel)', 'Allen, Mr. William Henry', ..., 'Montvila, Rev. Juozas', 'Graham, Miss. Margaret Edith', 'Johnston, Miss. Catherine Helen "Carrie"', 'Behr, Mr. Karl Howell', 'Dooley, Mr. Patrick']
# Length: 891
# Categories (891, object): ['Abbing, Mr. Anthony', 'Abbott, Mr. Rossmore Edward', 'Abbott, Mrs. Stanton (Rosa Hunt)', 'Abelson, Mr. Samuel', ..., 'de Pelsmaeker, Mr. Alfons', 'del Carlo, Mr. Sebastiano', 'van Billiard, Mr. Austin Blyler', 'van Melkebeke, Mr. Philemon']

# %%
pd.Categorical(data["Survived"])
# Out:
# [0, 1, 1, 1, 0, ..., 0, 1, 0, 1, 0]
# Length: 891
# Categories (2, int64): [0, 1]

# %%
data["Cabin"].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
data[data["Age"]>18]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data[data["Age"]>50]
# Out:
#      PassengerId  Survived  Pclass  \
# 6              7         0       1
# 11            12         1       1
# 15            16         1       2
# 33            34         0       2
# 54            55         0       1
# ..           ...       ...     ...
# 820          821         1       1
# 829          830         1       1
# 851          852         0       3
# 857          858         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 33                               Wheadon, Mr. Edward H    male  66.0      0
# 54                      Ostby, Mr. Engelhart Cornelius    male  65.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
len(data[data["Age"]>50])
# Out:
# 64

# %%
len(data[data["Age"]>50])-891
# Out:
# -827

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare  new_col  my_data         sum
# count  891.000000  891.000000    891.0    891.0  714.000000
# mean     0.381594   32.204208      0.0      2.0  478.281751
# std      0.806057   49.693429      0.0      0.0  260.060262
# min      0.000000    0.000000      0.0      2.0   10.000000
# 25%      0.000000    7.910400      0.0      2.0  249.125000
# ...

# %%
data[data["Fare"]>32.204208][1:4]
# Out:
#     PassengerId  Survived  Pclass  \
# 3             4         1       1
# 6             7         0       1
# 23           24         1       1
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 3   Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 6                        McCarthy, Mr. Timothy J    male  54.0      0      0
# 23                  Sloper, Mr. William Thompson    male  28.0      0      0
#
#     Ticket     Fare Cabin Embarked  new_col  my_data   sum  \
# 3   113803  53.1000  C123        S        0        2  39.0
# 6    17463  51.8625   E46        S        0        2  61.0
# 23  113788  35.5000    A6        S        0        2  52.0
#
#                                                  info
# 3   femaleFutrelle, Mrs. Jacques Heath (Lily May P...
# 6                         maleMcCarthy, Mr. Timothy J
# 23                   maleSloper, Mr. William Thompson

# %%
data[data["Name"]=="Braund, Mr. Owen Harris"]
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked  new_col  my_data   sum  \
# 0      0  A/5 21171  7.25   NaN        S        0        2  23.0
#
#                           info
# 0  maleBraund, Mr. Owen Harris

# %%
len(data[data["Fare"]==0])
# Out:
# 15

# %%
len(data[data["Sex"]=="male"])
# Out:
# 577

# %%
pd.Categorical(data["Sex"])
# Out:
# ['male', 'female', 'female', 'female', 'male', ..., 'male', 'female', 'female', 'male', 'male']
# Length: 891
# Categories (2, object): ['female', 'male']

# %%
len(data[data["Survived"]==1])
# Out:
# 342

# %%
data[data["Pclass"] == 2]
# Out:
#      PassengerId  Survived  Pclass  \
# 9             10         1       2
# 15            16         1       2
# 17            18         1       2
# 20            21         0       2
# 21            22         1       2
# ..           ...       ...     ...
# 866          867         1       2
# 874          875         1       2
# 880          881         1       2
# 883          884         0       2
# 886          887         0       2
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 9             Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1      0
# 15               Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0      0
# 17                   Williams, Mr. Charles Eugene    male   NaN      0      0
# 20                           Fynney, Mr. Joseph J    male  35.0      0      0
# 21                          Beesley, Mr. Lawrence    male  34.0      0      0
# ...

# %%
data["joy"]=1

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data["Sex"]=="female"
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888     True
# 889    False
# 890    False
# Name: Sex, Length: 891, dtype: bool

# %%
data["Fare"]>32
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Fare, Length: 891, dtype: bool

# %%
# combine 2 condition

# %%
len(data[(data["Sex"]=="female" ) & (data["Fare"]>32)])
# Out:
# 104

# %%
data[(data["Sex"]=="female")&(data["Fare"]>32)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 31            32         1       1
# 43            44         1       2
# 52            53         1       1
# ..           ...       ...     ...
# 853          854         1       1
# 856          857         1       1
# 863          864         0       3
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 43            Laroche, Miss. Simonne Marie Anne Andree  female   3.0      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
data[(data["Survived"]==1)&(data["Sex"]=="male")]
# Out:
#      PassengerId  Survived  Pclass                             Name   Sex  \
# 17            18         1       2     Williams, Mr. Charles Eugene  male
# 21            22         1       2            Beesley, Mr. Lawrence  male
# 23            24         1       1     Sloper, Mr. William Thompson  male
# 36            37         1       3                 Mamee, Mr. Hanna  male
# 55            56         1       1                Woolner, Mr. Hugh  male
# ..           ...       ...     ...                              ...   ...
# 838          839         1       3                  Chip, Mr. Chang  male
# 839          840         1       1             Marechal, Mr. Pierre  male
# 857          858         1       1           Daly, Mr. Peter Denis   male
# 869          870         1       3  Johnson, Master. Harold Theodor  male
# 889          890         1       1            Behr, Mr. Karl Howell  male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked  new_col  my_data  \
# ...

# %%
len(data[(data["Survived"]==1)&(data["Sex"]=="male")])
# Out:
# 109

# %%
len(data[(data["Survived"]==1)&(data["Sex"]=="female")])
# Out:
# 233

# %%
max(data["Fare"])
# Out:
# 512.3292

# %%
data[data["Name"]==max(data["Fare"])]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, new_col, my_data, sum, info, joy]
# Index: []

# %%
data["Fare"] ==max(data["Fare"])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Fare, Length: 891, dtype: bool

# %%
data[data["Fare"]==max(data["Fare"])]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  \
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
#
#      new_col  my_data    sum                                    info  joy
# 258        0        2  294.0                  femaleWard, Miss. Anna    1
# 679        0        2  716.0  maleCardeza, Mr. Thomas Drake Martinez    1
# 737        0        2  773.0              maleLesurer, Mr. Gustave J    1

# %%
len(data[data["Fare"]==max(data["Fare"])])
# Out:
# 3

# %%
data[data["Fare"]==max(data["Fare"])]["Name"]
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
data[data["Fare"]==max(data["Fare"])]["Sex"]
# Out:
# 258    female
# 679      male
# 737      male
# Name: Sex, dtype: object

# %%
#row

# %%
data[0:2]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked  new_col  my_data   sum  \
# 0      0  A/5 21171   7.2500   NaN        S        0        2  23.0
# 1      0   PC 17599  71.2833   C85        C        0        2  40.0
#
#                                                 info  joy
# 0                        maleBraund, Mr. Owen Harris    1
# 1  femaleCumings, Mrs. John Bradley (Florence Bri...    1

# %%
data[3:4]
# Out:
#    PassengerId  Survived  Pclass  \
# 3            4         1       1
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
#
#    Ticket  Fare Cabin Embarked  new_col  my_data   sum  \
# 3  113803  53.1  C123        S        0        2  39.0
#
#                                                 info  joy
# 3  femaleFutrelle, Mrs. Jacques Heath (Lily May P...    1

# %%
data[0:891:2]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 4              5         0       3
# 6              7         0       1
# 8              9         1       3
# ..           ...       ...     ...
# 882          883         0       3
# 884          885         0       3
# 886          887         0       2
# 888          889         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data[0::2]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 4              5         0       3
# 6              7         0       1
# 8              9         1       3
# ..           ...       ...     ...
# 882          883         0       3
# 884          885         0       3
# 886          887         0       2
# 888          889         0       3
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 4                             Allen, Mr. William Henry    male  35.0      0
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# row column intersection

# %%
data[["PassengerId","Survived","Pclass"]][0:4]
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1

# %%
data.iloc[0:2]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked  new_col  my_data   sum  \
# 0      0  A/5 21171   7.2500   NaN        S        0        2  23.0
# 1      0   PC 17599  71.2833   C85        C        0        2  40.0
#
#                                                 info  joy
# 0                        maleBraund, Mr. Owen Harris    1
# 1  femaleCumings, Mrs. John Bradley (Florence Bri...    1

# %%
data.b

# %% [markdown]
# loc vs iloc :- iloc inbuild function leta he
#                loc named value leta he

# %%
data.loc[0:2,["PassengerId","Survived","Pclass"]]
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3

# %%
data.iloc[0:2,[0,1,2]]
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3
# 1            2         1       1
